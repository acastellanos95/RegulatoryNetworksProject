# %%
D = DiGraph([(1,0),(8,0),(0,1),(3,1),(5,2),(6,2),(1,3),(7,3),(6,4),(0,4),(3,5),(1,5),(7,6),(4,6),(5,7),(2,7)])
H = D.plot(graph_border=True)
H.show()
# Out:
# Graphics object consisting of 35 graphics primitives

# %%
D = DiGraph([(1,0),(0,1),(8,0),(0,1),(3,1),(5,2),(6,2),(1,3),(7,3),(6,4),(0,4),(3,5),(1,5),(7,6),(4,6),(5,7),(2,7)])
H = D.plot(graph_border=True)
H.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b6f316f9704a> in <module>
# ----> 1 D = DiGraph([(Integer(1),Integer(0)),(Integer(1),Integer(1)),(Integer(0),Integer(1)),(Integer(8),Integer(0)),(Integer(0),Integer(1)),(Integer(3),Integer(1)),(Integer(5),Integer(2)),(Integer(6),Integer(2)),(Integer(1),Integer(3)),(Integer(7),Integer(3)),(Integer(6),Integer(4)),(Integer(0),Integer(4)),(Integer(3),Integer(5)),(Integer(1),Integer(5)),(Integer(7),Integer(6)),(Integer(4),Integer(6)),(Integer(5),Integer(7)),(Integer(2),Integer(7))])
#       2 H = D.plot(graph_border=True)
#       3 H.show()
#
# ~/Downloads/SageMath/local/lib/python3.9/site-packages/sage/graphs/digraph.py in __init__(self, data, pos, loops, format, weighted, data_structure, vertex_labels, name, multiedges, convert_empty_dict_labels_to_None, sparse, immutable)
# ...
